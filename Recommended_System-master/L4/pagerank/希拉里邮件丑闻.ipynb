# %%
# -*- coding: utf-8 -*-
# 用PageRank挖掘希拉里邮件中的重要人物关系
import pandas as pd
import networkx as nx
import numpy as np
from collections import defaultdict
import matplotlib.pyplot as plt

# %%
emails = pd.read_csv('Emails.csv')
emails.head(10)
# Out:
#    Id  DocNumber                                    MetadataSubject  \
# 0   1  C05739545                                                WOW
# 1   2  C05739546  H: LATEST: HOW SYRIA IS AIDING QADDAFI AND MOR...
# 2   3  C05739547                                      CHRIS STEVENS
# 3   4  C05739550                         CAIRO CONDEMNATION - FINAL
# 4   5  C05739554  H: LATEST: HOW SYRIA IS AIDING QADDAFI AND MOR...
# 5   6  C05739559  MEET THE RIGHT-WING EXTREMIST BEHIND ANTI-MUSL...
# 6   7  C05739560  ANTI-MUSLIM FILM DIRECTOR IN HIDING, FOLLOWING...
# 7   8  C05739561  H: LATEST: HOW SYRIA IS AIDING QADDAFI AND MOR...
# 8   9  C05739562                                SECRETARY'S REMARKS
# 9  10  C05739563                                      MORE ON LIBYA
#
#           MetadataTo       MetadataFrom  SenderPersonId  \
# 0                  H  Sullivan, Jacob J            87.0
# 1                  H                NaN             NaN
# ...

# %%
emails.shape
# Out:
# (7945, 22)

# %%
# emails.info()

# %%
# emails.MetadataFrom.value_counts()

# %%
file = pd.read_csv("./Aliases.csv")
file.head()
#aliases  {别名：ID}
aliases = {}
for index, row in file.iterrows():  #iterrows()返回索引和行对象组成的元组
    aliases[row['Alias']] = row['PersonId']

# %%
file_person = pd.read_csv("./Persons.csv")
file_person.head()
#persons {ID:真名}
persons = {}
for index, row in file_person.iterrows():
    persons[row['Id']] = row['Name']
# persons.items()

# %%
#别名转换
def unify_name(name):
    lower_str = str(name).lower()
    name = lower_str.replace(',','').split('@')[0]
    if name in aliases.keys():
        return persons[aliases[name]]
    return name

# %%
emails.MetadataFrom.apply(unify_name)
emails.MetadataTo.apply(unify_name)
print(emails.MetadataTo[:30])
# Out:
# 0                        H
# 1                        H
# 2                       ;H
# 3                        H
# 4             Abedin, Huma
# 5        Russorv@state.gov
# 6                        H
# 7             Abedin, Huma
# 8                        H
# 9                        H
# 10                       H
# 11                       H
# 12                       H
# 13                       H
# 14                       H
# 15                       H
# 16                       H
# 17                       H
# 18                       H
# 19        Sherman, Wendy R
# 20    sullivanjj@state.gov
# 21       Russorv@state.gov
# 22       Russorv@state.gov
# 23    sullivanjj@state.gov
# 24                       H
# 25                       H
# 26                       H
# 27                       H
# 28                       H
# 29                       H
# Name: MetadataTo, dtype: object
